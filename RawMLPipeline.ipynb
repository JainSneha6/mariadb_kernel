-- %%
SHOW DATABASES;
-- Out:
-- <html><body><table border="1" style="margin-left: 0"><tr><th style="text-align:left;white-space:pre">Database</th></tr><tr><td style="text-align:left;white-space:pre">information_schema</td></tr><tr><td style="text-align:left;white-space:pre">mysql</td></tr><tr><td style="text-align:left;white-space:pre">performance_schema</td></tr><tr><td style="text-align:left;white-space:pre">sys</td></tr><tr><td style="text-align:left;white-space:pre">test</td></tr></table></body></html>

-- %%
CREATE DATABASE BUGBREW;
-- Out:
-- Query OK

-- %%
USE BUGBREW;
-- Out:
-- Query OK

-- %%
SELECT * FROM IRIS;
-- Out:
-- <html><body><table border="1" style="margin-left: 0"><tr><th style="text-align:left;white-space:pre">Id</th><th style="text-align:left;white-space:pre">SepalLengthCm</th><th style="text-align:left;white-space:pre">SepalWidthCm</th><th style="text-align:left;white-space:pre">PetalLengthCm</th><th style="text-align:left;white-space:pre">PetalWidthCm</th><th style="text-align:left;white-space:pre">Species</th></tr><tr><td style="text-align:left;white-space:pre">1</td><td style="text-align:left;white-space:pre">5.1</td><td style="text-align:left;white-space:pre">3.5</td><td style="text-align:left;white-space:pre">1.4</td><td style="text-align:left;white-space:pre">0.2</td><td style="text-align:left;white-space:pre">Iris-setosa
-- ...

-- %%
%missing
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>missing</th>
--       <th>percent</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>Id</th>
--       <td>0</td>
--       <td>0.00</td>
--     </tr>
--     <tr>
--       <th>SepalLengthCm</th>
--       <td>2</td>
--       <td>1.33</td>
--     </tr>
--     <tr>
--       <th>SepalWidthCm</th>
--       <td>3</td>
--       <td>2.00</td>
--     </tr>
--     <tr>
--       <th>PetalLengthCm</th>
--       <td>1</td>
--       <td>0.67</td>
--     </tr>
--     <tr>
--       <th>PetalWidthCm</th>
--       <td>0</td>
--       <td>0.00</td>
--     </tr>
--     <tr>
--       <th>Species</th>
--       <td>2</td>
--       <td>1.33</td>
--     </tr>
--   </tbody>
-- </table>

-- %%
%dropmissing mode=preview
-- Out:
-- PREVIEW: would drop 8 row(s) (from 150 to 142).
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th>Id</th>
--       <th>SepalLengthCm</th>
--       <th>SepalWidthCm</th>
--       <th>PetalLengthCm</th>
--       <th>PetalWidthCm</th>
--       <th>Species</th>
--       <th>_would_be_dropped</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <td>7</td>
--       <td>4.6</td>
--       <td>NaN</td>
--       <td>1.4</td>
--       <td>0.3</td>
--       <td>Iris-setosa</td>
--       <td>True</td>
--     </tr>
--     <tr>
--       <td>14</td>
--       <td>4.3</td>
--       <td>3.0</td>
--       <td>1.1</td>
--       <td>0.1</td>
--       <td>NaN</td>
--       <td>True</td>
--     </tr>
--     <tr>
--       <td>17</td>
--       <td>5.4</td>
--       <td>NaN</td>
--       <td>1.3</td>
--       <td>0.1</td>
--       <td>Iris-setosa</td>
--       <td>True</td>
--     </tr>
--     <tr>
--       <td>28</td>
--       <td>NaN</td>
-- ...

-- %%
%fillmissing mode=preview
-- Out:
-- PREVIEW: missing counts per column:
-- Id: missing=0
-- SepalLengthCm: missing=2
-- SepalWidthCm: missing=3
-- PetalLengthCm: missing=1
-- PetalWidthCm: missing=0
-- Species: missing=2
-- PREVIEW: computed fill-values (best-effort):
-- Id: would fill with -> 75.5 (mean via local preview)
-- SepalLengthCm: would fill with -> 5.847297297297298 (mean via local preview)
-- SepalWidthCm: would fill with -> 3.042857142857143 (mean via local preview)
-- PetalLengthCm: would fill with -> 3.773154362416107 (mean via local preview)
-- PetalWidthCm: would fill with -> 0.1093333333333333 (mean via local preview)
-- Species: could NOT determine fill value (not numeric; cannot compute mean locally); would skip
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th>Id</th>
--       <th>SepalLengthCm</th>
--       <th>SepalWidthCm</th>
--       <th>PetalLengthCm</th>
--       <th>PetalWidthCm</th>
--       <th>Species</th>
-- ...

-- %%
%outliers
-- Out:
-- Outlier detection completed (non in-place). Summary:
-- Column 'Id': detected 0 outlier(s) using iqr.
-- Column 'SepalLengthCm': detected 0 outlier(s) using iqr.
-- Column 'SepalWidthCm': detected 4 outlier(s) using iqr.
-- Column 'PetalLengthCm': detected 0 outlier(s) using iqr.
-- Column 'PetalWidthCm': detected 11 outlier(s) using iqr.
-- Results stored in data['last_select_outliers'] (original data['last_select'] unchanged).
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th>Id</th>
--       <th>SepalLengthCm</th>
--       <th>SepalWidthCm</th>
--       <th>PetalLengthCm</th>
--       <th>PetalWidthCm</th>
--       <th>Species</th>
--       <th>Id_is_outlier</th>
--       <th>SepalLengthCm_is_outlier</th>
--       <th>SepalWidthCm_is_outlier</th>
--       <th>PetalLengthCm_is_outlier</th>
--       <th>PetalWidthCm_is_outlier</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <td>1</td>
--       <td>5.1</td>
-- ...

-- %%
%clipoutliers mode=preview
-- Out:
-- PREVIEW (local): would modify 15 value(s) across 5 column(s).
-- Column 'Id': would clip 0 value(s) locally (bounds: -73.5, 224.5).
-- Column 'SepalLengthCm': would clip 0 value(s) locally (bounds: 3.1499999999999986, 8.350000000000001).
-- Column 'SepalWidthCm': would clip 4 value(s) locally (bounds: 2.05, 4.05).
-- Column 'PetalLengthCm': would clip 0 value(s) locally (bounds: -3.649999999999999, 10.349999999999998).
-- Column 'PetalWidthCm': would clip 11 value(s) locally (bounds: 0.1, 0.1).
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th>Id</th>
--       <th>SepalLengthCm</th>
--       <th>SepalWidthCm</th>
--       <th>PetalLengthCm</th>
--       <th>PetalWidthCm</th>
--       <th>Species</th>
--       <th>_oob_columns</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <td>1</td>
--       <td>5.1</td>
--       <td>3.5</td>
--       <td>1.4</td>
--       <td>0.2</td>
--       <td>Iris-setosa</td>
-- ...

-- %%
%encode
